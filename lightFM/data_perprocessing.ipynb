# %% [markdown]
# ## Data preprocessing for LightFM

# %%
import numpy as np
import pandas as pd

# all lightfm imports 
from lightfm.data import Dataset
from lightfm import LightFM
from lightfm import cross_validation
from lightfm.evaluation import precision_at_k
from lightfm.evaluation import auc_score

# imports re for text cleaning 
import re
from datetime import datetime, timedelta

# we will ignore pandas warning 
import warnings
warnings.filterwarnings('ignore')

from main import *

from scipy.sparse import csr_matrix
# Out:
# C:\Users\marya\miniconda3\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn(

# %%
# Read data, drop useless column 
df_fst_tests = pd.read_csv("data/init_tests.csv").drop("Unnamed: 0", axis= 'columns')
df_snd_tests = pd.read_csv("data/second_tests.csv").drop("Unnamed: 0", axis= 'columns')
df_personal_attributes = pd.read_csv("data/personal_attributes.csv").drop("Unnamed: 0", axis= 'columns')

# %%
# calculate the diff per skill, concat the dataframes 
df_all = df_personal_attributes
for col in df_fst_tests.columns[1:]:
    df_all[f'diff_{col}'] = df_snd_tests[col]- df_fst_tests[col]
df_all['action'] = df_snd_tests['action']

# %%
df_all
# Out:
#      student_id                  gender  age prior_education  \
# 0             0                    Male   18       Gymnasium
# 1             1  I would rather not say   20             VWO
# 2             2  I would rather not say   19            HAVO
# 3             3                  Female   24            HAVO
# 4             4  I would rather not say   17       Gymnasium
# ..          ...                     ...  ...             ...
# 995         995  I would rather not say   18            HAVO
# 996         996  I would rather not say   19       Gymnasium
# 997         997  I would rather not say   21             VWO
# 998         998  I would rather not say   20            HAVO
# 999         999  I would rather not say   20       Gymnasium
#
#           course_of_studies  year_of_study    nationality parent_occupation  \
# 0    International business              0        Chinese            Doctor
# 1    International business              1  South-African            Doctor
# 2    International business              2            USA       Taxi driver
# 3    International business              3       Japanese            Doctor
# 4    International business              1        Belgium               NaN
# ..                      ...            ...            ...               ...
# 995  International business              3         German          Gardener
# 996  International business              0        Chinese        Life coach
# 997  International business              1          Dutch            Doctor
# 998  International business              2       Japanese       Taxi driver
# 999  International business              2        Belgium            Doctor
#
#     previous_international_experience                       languages  \
# 0                    Exchange student         ['English', 'Mandarin']
# 1     Internship in a foreign country            ['Dutch', 'English']
# 2                            Gap year                     ['English']
# 3         Worked in a foreign country         ['English', 'Japanese']
# 4     Internship in a foreign country           ['English', 'French']
# ..                                ...                             ...
# 995                          Gap year           ['English', 'German']
# 996                  Exchange student         ['English', 'Mandarin']
# 997                  Exchange student  ['Dutch', 'English', 'German']
# 998   Internship in a foreign country         ['English', 'Japanese']
# 999                          Gap year           ['English', 'French']
#
#      diff_openness  diff_cultural_empathy  diff_openmindness  \
# 0        -0.009194              -0.041855           0.236599
# 1         0.340767               0.439234           0.545912
# 2         0.005678              -0.013036           0.013779
# 3         0.145423               0.290494           0.443662
# 4         0.532262               0.351150           0.285170
# ..             ...                    ...                ...
# 995       0.162114               0.232295           0.066447
# 996      -0.078027              -0.069645           0.097114
# 997       0.111530               0.081480           0.138906
# 998       0.389337               0.291267           0.233677
# 999      -0.077978              -0.067487           0.069710
#
#      diff_adaptability  diff_flexibility  diff_emotional_stability  \
# 0             0.472443          0.143547                 -0.076754
# 1             0.901928          0.401027                  0.721604
# 2             0.062889         -0.154355                 -0.154360
# 3             0.436655          0.172129                  0.711872
# 4             0.424398          0.974405                  0.710348
# ..                 ...               ...                       ...
# 995           0.088428          0.680674                  0.234471
# 996           0.207007         -0.041772                 -0.200032
# 997           0.113138         -0.031199                  0.117021
# 998           0.427105          0.349768                  0.614151
# 999           0.183142         -0.112407                 -0.234212
#
#      diff_social_initiative                    action
# 0                 -0.038781          Language courses
# 1                  0.356028  Extra-curricular Courses
# 2                  0.137602                  Blogging
# 3                  0.322262  Extra-curricular Courses
# 4                  0.408109                       IVC
# ..                      ...                       ...
# 995                0.296292                       IVC
# 996               -0.108070          Language courses
# 997                0.115254                      CCCC
# 998                0.300658                      CCCC
# 999               -0.180018          Language courses
#
# [1000 rows x 18 columns]

# %% [markdown]
# ## LightFM

# %%
model = LightFM(
    no_components=150,
    learning_rate=0.05,
    loss='warp',
    random_state=2019)
